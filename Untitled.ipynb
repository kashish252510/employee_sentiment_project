# %%
import shutil
shutil.rmtree(r"emp/Visualization")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import shutil
# ----> 2 shutil.rmtree(r"employee_sentiment_project/Visualization")
#
# File ~\anaconda3\Lib\shutil.py:780, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     778     st = os.lstat(path)
#     779 except OSError as err:
# --> 780     onexc(os.lstat, path, err)
#     781     return
#     782 try:
#
# File ~\anaconda3\Lib\shutil.py:778, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     776     raise NotImplementedError("dir_fd unavailable on this platform")
#     777 try:
# --> 778     st = os.lstat(path)
#     779 except OSError as err:
#     780     onexc(os.lstat, path, err)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'employee_sentiment_project/Visualization'
